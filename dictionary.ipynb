# %% [markdown]
# # dictionary : Mutable, no duplicates, keys are unique

# %%
employee = {"ID":"101", "name":"aarti dorale", "department":"IT"} 
print(employee)
# Out:
# {'ID': '101', 'name': 'aarti dorale', 'department': 'IT'}

# %%
employee.keys()
# Out:
# dict_keys(['ID', 'name', 'department'])

# %%
employee.values()
# Out:
# dict_values(['101', 'aarti dorale', 'IT'])

# %%
employee["salary"]=200000 #add,update
print(employee)
# Out:
# {'ID': '101', 'name': 'aarti dorale', 'department': 'IT', 'salary': 200000}

# %%
employee["ID1"] = 101
print(employee)
# Out:
# {'ID': '101', 'name': 'aarti dorale', 'department': 'IT', 'salary': 200000, 'ID1': 101}

# %%
employee
# Out:
# {'ID': '101',
#  'name': 'aarti dorale',
#  'department': 'IT',
#  'salary': 200000,
#  'ID1': 101}

# %%
#que? conert list into dictionary
# subject=["DS","AI","cloud","java"] #list
# marks=[50,60,70,90]

# %%
subject=["DS","AI","cloud","java"] #list
marks=[50,60,70,90]
sub=zip(subject,marks) #zip() function for coverting list into dictionary
sub=dict(sub)
print(sub) 
# print(sub) <zip object at 0x00000147CCB9AA40> : zip object jo process madhey aahe.
# Out:
# {'DS': 50, 'AI': 60, 'cloud': 70, 'java': 90}

# %%
total_marks = sum(sub.values())
print(total_marks)
# Out:
# 270

# %%
per=(total_marks/len(sub.values()))
print(per)
# Out:
# 67.5

# %%
sub.pop("java")
print(sub)
# Out:
# {'DS': 50, 'AI': 60, 'cloud': 70}

# %%
subject=list(sub.keys())
print(subject)
# Out:
# ['DS', 'AI', 'cloud']

# %% [markdown]
# ## final revision

# %% [markdown]
# # functions:
# ### len(), str(), dict()

# %%
student = {"name" : "aarti", "age": 22, "marks":95, "course": "DA"}
print(student)
# Out:
# {'name': 'aarti', 'age': 22, 'marks': 95, 'course': 'DA'}

# %%
# len()
print(len(student))
# Out:
# 4

# %%
str(student)
# Out:
# "{'name': 'aarti', 'age': 22, 'marks': 95, 'course': 'DA'}"

# %%
type(student)
# Out:
# dict

# %%
# empty dictionary: dict()
d = dict()
print(d)
# Out:
# {}

# %% [markdown]
# ### methods

# %%
student.get("name")
# Out:
# 'aarti'

# %%
student.keys()
# Out:
# dict_keys(['name', 'age', 'marks', 'course'])

# %%
student.values()
# Out:
# dict_values(['aarti', 22, 95, 'DA'])

# %%
student.items()
# Out:
# dict_items([('name', 'aarti'), ('age', 22), ('marks', 95), ('course', 'DA')])

# %%
student.update({"name":"bharti", "age" : 23})
print(student)
# Out:
# {'name': 'bharti', 'age': 23, 'marks': 95, 'course': 'DA'}

# %%
student.pop("marks")
# Out:
# 95

# %%
print(student)
# Out:
# {'name': 'bharti', 'age': 23, 'course': 'DA'}

# %%
student.clear()

# %%
print(student)
# Out:
# {}

# %% [markdown]
# ### zip : to convert list to dict

# %%
list1 = ["A","B","C","D"]
list2 = [67,89,90,6]

# %%
a = zip(list1, list2)
a = dict(a)
print(a)
# Out:
# {'A': 67, 'B': 89, 'C': 90, 'D': 6}
