# %% [markdown]
# ## string : collection of characters

# %%
string = "data science"
print(string.lower())
print(string.upper())
print(string.title())
print(string.capitalize())
# Out:
# data science
# DATA SCIENCE
# Data Science
# Data science

# %%
subject = "python"
print(subject)
# Out:
# python

# %%
subject.startswith('p')
# Out:
# True

# %%
subject.endswith('p')
# Out:
# False

# %%
subject.isalpha()
# Out:
# True

# %%
subject.isdigit()
# Out:
# False

# %%
s="123"
s.isdigit()
# Out:
# True

# %%
fname = "aarti"
lname = "dorale"
print(fname,end=" "+lname)
# Out:
# aarti dorale

# %%
print(fname," ",lname)
# Out:
# aarti   dorale

# %%
s1 = "   data    "
print(s1)
# Out:
#    data

# %%
# s1 = s1.rstrip()
# print(s1)
# Out:
#    data

# %%
s1.lstrip()
# Out:
# 'data    '

# %%
print(s1)
# Out:
#    data

# %%
a = "data analyst"
print(a.upper())
print(a.lower())
print(a.title())
print(a.index("a"))
print(a.find("d"))
# Out:
# DATA ANALYST
# data analyst
# Data Analyst
# 1
# 0

# %% [markdown]
# ### difference: index and find

# %%
print(a.index("i"))  # gives error
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 print(a.index("i"))
#
# ValueError: substring not found

# %%
print(a.find("g")) # return -1
# Out:
# -1

# %% [markdown]
# ## split

# %%
a = "#fgf#hgfh#dgdfg#gdfgdr#"
print(a.split("#"))
# Out:
# ['', 'fgf', 'hgfh', 'dgdfg', 'gdfgdr', '']

# %% [markdown]
# #### startswith, endswith

# %%
s = "Harry Potter"
print(s.startswith("H"))
# Out:
# True

# %%
print(s.endswith("r"))
# Out:
# True

# %%
print(s.endswith("R"))
# Out:
# False

# %%
## Slicing

a = "Harry potter and fire"
print(a[0:5]) 
print(a[6:9])
print(a[:5]) 
print(a[4:])
print(a[-4:])
print(a[::2])
print
# Out:
# Harry
# pot
# Harry
# y potter and fire
# fire
