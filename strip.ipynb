# %%
str1 = "      aarti dorale          "
s1 = str1.strip()
print(s1)
# Out:
# aarti dorale

# %%
class Student:
    def __init__(self, name, age):
        self.name = name
        self.age = age

s1 = Student("aarti", 22)
