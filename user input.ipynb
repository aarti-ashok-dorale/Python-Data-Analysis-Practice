# %% [markdown]
# ## user input  = ask for input from user

# %%
name = input("enter your name:") # by default string 
print(name)
# Out:
# enter your name: aarti
# aarti

# %%
age = int(input("entert ypur age:"))
print(age)
# Out:
# entert ypur age: 12
# 12

# %%
number = float(input("enter number:"))
print(number)
# Out:
# enter number: 34
# 34.0

# %%
eval = eval(input("enter your expression:"))
print(eval)
# Out:
# enter your expression: 2+4
# 6
