# %%
string = "data science"
print(string.lower())
print(string.upper())
print(string.title())
print(string.capitalize())
# Out:
# data science
# DATA SCIENCE
# Data Science
# Data science

# %%
subject = "python"
print(subject)
# Out:
# python

# %%
subject.startswith('p')
# Out:
# True

# %%
subject.endswith('p')
# Out:
# False

# %%
subject.isalpha()
# Out:
# True

# %%
subject.isdigit()
# Out:
# False

# %%
s="123"
s.isdigit()
# Out:
# True

# %%
fname = "aarti"
lname = "dorale"
print(fname,end=" "+lname)
# Out:
# aarti dorale

# %%
print(fname," ",lname)
# Out:
# aarti   dorale

# %%
s1 = "   data    "
print(s1)
# Out:
#    data

# %%
# s1 = s1.rstrip()
# print(s1)
# Out:
#    data

# %%
s1.lstrip()
# Out:
# 'data    '

# %%
print(s1)
# Out:
#    data
