# %%
#student
student_name="Aarti Dorale"
student_age=22
course_name="Data Science"
per=90.89

print(student_name,student_age,course_name,per)
# Out:
# Aarti Dorale 22 Data Science 90.89

# %%
#employee
emp_name="Priya Diwan"
emp_role="Data Analyst"
salary=30000
age=25

print(emp_name,emp_role,salary,age)
# Out:
# Priya Diwan Data Analyst 30000 25

# %%
#product
product_name="Toothpaste"
id="T_24"
product_MFG="02/04/2026"
product_EXP="02/04/2027"
quantity=5
price=20

print(product_name,id,product_MFG,product_EXP,quantity,price)
# Out:
# Toothpaste T_24 02/04/2026 02/04/2027 5 20

# %%
x,y,z = 1,2,3
print(x,y,z)
# Out:
# 1 2 3

# %%
a=b=c=10
print(a,b,c)
# Out:
# 10 10 10
