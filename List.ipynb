# %% [markdown]
# ## list --[], mutable(changable), duplicate values are allowed, ordered(MDO)

# %%
num=[1,2,3,4,5,5,6,7,8,9,10]
print(num)
# Out:
# [1, 2, 3, 4, 5, 5, 6, 7, 8, 9, 10]

# %%
type(num)
# Out:
# list

# %%
student=[101,"Aarti Dorale","DS",94.60]
print(student)
# Out:
# [101, 'Aarti Dorale', 'DS', 94.6]

# %% [markdown]
# 1.Append -- add elements at the last position
# 2.Extend -- add multiple elements at the last position
# 3.Insert -- add single value in specific position(position, value)
# 4.Remove() -- remove value of specific position
# 5.pop() -- delete the last element
# 6.index() -- to find the index of element
# 7.R
# everse() -- reverse all over list
# 8.sort() -- elements in ascending order
# 9.copy() -- creating new variable and copy the old variable's value
# 10.del() -- delete newly created variable
# 11.sum  -- sum of elememts
# 12.min -- minimun number from list
# 13.max -- maximun number from list
# 14.len  -- show the length of list
# 15.count -- count of specific elememt from list

# %%
num.append(101)
print(num)
# Out:
# [1, 2, 3, 4, 5, 5, 6, 7, 8, 9, 10, 101]

# %%
num.extend([101,102,103,104,105])
print(num)
# Out:
# [1, 2, 3, 4, 5, 5, 6, 7, 8, 9, 10, 101, 101, 102, 103, 104, 105]

# %%
num.insert(3,1000) 
print(num)
# Out:
# [1, 2, 3, 1000, 4, 5, 5, 6, 7, 8, 9, 10, 101, 101, 102, 103, 104, 105]

# %%
fruits=['apple','banana','cherry','pineapple']
print(fruits)
# Out:
# ['apple', 'banana', 'cherry', 'pineapple']

# %%
type(fruits)
# Out:
# list

# %%
fruits.append('kiwi')
print(fruits)
# Out:
# ['apple', 'banana', 'cherry', 'pineapple', 'kiwi']

# %%
fruits.append('mango')
print(fruits)
# Out:
# ['apple', 'banana', 'cherry', 'pineapple', 'kiwi', 'mango']

# %%
fruits.extend(['orange','watermelon','dragon'])
print(fruits)
# Out:
# ['apple', 'banana', 'cherry', 'pineapple', 'kiwi', 'mango', 'orange', 'watermelon', 'dragon']

# %%
num.remove(5)
print(num)
# Out:
# [1, 2, 3, 1000, 4, 5, 6, 7, 8, 9, 10, 101, 101, 102, 103, 104, 105]

# %%
num.pop()
print(num)
# Out:
# [1, 2, 3, 1000, 4, 5, 6, 7, 8, 9, 10, 101, 101, 102, 103, 104]

# %%
num.index(3)
# Out:
# 2

# %%
num[2]=2000
print(num)
# Out:
# [1, 2, 2000, 1000, 4, 5, 6, 7, 8, 9, 10, 101, 101, 102, 103, 104]

# %%
num.reverse()
print(num)
# Out:
# [104, 103, 102, 101, 101, 10, 9, 8, 7, 6, 5, 4, 1000, 2000, 2, 1]

# %%
num.sort()
print(num)
# Out:
# [1, 2, 4, 5, 6, 7, 8, 9, 10, 101, 101, 102, 103, 104, 1000, 2000]

# %%
num.reverse()
print(num)
# Out:
# [2000, 1000, 104, 103, 102, 101, 101, 10, 9, 8, 7, 6, 5, 4, 2, 1]

# %%
num1=num.copy
print(num1)
# Out:
# <built-in method copy of list object at 0x000002B099D453C0>

# %%
del num1

# %%
num=[10,20,30,40,50,60,60]
print(num)
# Out:
# [10, 20, 30, 40, 50, 60, 60]

# %%
sum(num)
# Out:
# 270

# %%
min(num)
# Out:
# 10

# %%
max(num)
# Out:
# 60

# %% [markdown]
# len(num)

# %%
#count of occurence
num.count(60)
# Out:
# 2

# %%
list1 = [1,2,3,3,5,6,7,7,8,9,10] #To remove duplicates: convert into sets
print(set(list1))
# Out:
# {1, 2, 3, 5, 6, 7, 8, 9, 10}
